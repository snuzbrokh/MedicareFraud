# %%
import numpy as np
import pandas as pd
import scipy.stats

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/combinedData.csv')
target = pd.read_csv('../data/combinedTarget.csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (10,13,14,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data.merge(target, how='left',on=['Provider','Set'])

# %%
data.drop(columns = ['Unnamed: 0_x','Unnamed: 0_y'], inplace=True)

# %%
data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11011  CLM144521   2009-01-18  2009-01-18  PRV52314
#
#    InscClaimAmtReimbursed        AttendingPhysician OperatingPhysician  \
# 0                   26000       Dr. Gabriele Jockel                NaN
# 1                    5000         Dr. Swen Trujillo  Dr. Swen Trujillo
# 2                    5000  Dr. Horst-Dieter Chapman                NaN
# 3                    5000     Dr. Gerónimo Mülichen     Dr. Jiri Jones
# 4                      50        Dr. William Norton                NaN
#
#           OtherPhysician AdmissionDt  ... IPAnnualDeductibleAmt  \
# 0                    NaN  2009-04-12  ...                  3204
# 1                    NaN  2009-08-31  ...                  3204
# 2  Dr. Heather Blackburn  2009-09-17  ...                  3204
# 3       Dr. Brent Kramer  2009-02-14  ...                  1068
# 4                    NaN         NaN  ...                  1068
#
#    OPAnnualReimbursementAmt OPAnnualDeductibleAmt WhetherDead NumProc  \
# 0                        60                    70           0       0
# 1                        60                    70           0       1
# 2                        60                    70           0       0
# 3                       250                   320           0       1
# 4                       250                   320           0       0
#
#   NumClaims AdmissionDays ClaimDays   Age PotentialFraud
# 0        10           7.0         7  66.0            Yes
# 1         4           3.0         3  67.0             No
# 2         7           4.0         4  67.0             No
# 3        10           9.0         9  95.0             No
# 4         6           NaN         1  95.0             No
#
# [5 rows x 63 columns]

# %%
data.groupby(['Provider','Attending '])['ClaimID'].count()
# Out:
# Provider
# PRV51001      25
# PRV51002     205
# PRV51003     132
# PRV51004     149
# PRV51005    1165
#             ...
# PRV57759      28
# PRV57760      22
# PRV57761      82
# PRV57762       1
# PRV57763     118
# Name: ClaimID, Length: 6763, dtype: int64

# %%
data.melt(id_vars=['Provider','ClaimID'], value_vars=['AttendingPhysician','OperatingPhysician','OtherPhysician']).rename(columns=str.title)
# Out:
#          Provider    Claimid            Variable                     Value
# 0        PRV55912   CLM46614  AttendingPhysician       Dr. Gabriele Jockel
# 1        PRV55907   CLM66048  AttendingPhysician         Dr. Swen Trujillo
# 2        PRV56046   CLM68358  AttendingPhysician  Dr. Horst-Dieter Chapman
# 3        PRV52405   CLM38412  AttendingPhysician     Dr. Gerónimo Mülichen
# 4        PRV52314  CLM144521  AttendingPhysician        Dr. William Norton
# ...           ...        ...                 ...                       ...
# 2080804  PRV55485  CLM469576      OtherPhysician                       NaN
# 2080805  PRV55485  CLM483842      OtherPhysician                       NaN
# 2080806  PRV55485  CLM554925      OtherPhysician                       NaN
# 2080807  PRV55889  CLM347777      OtherPhysician          Dr. Lori Mcgrath
# 2080808  PRV52983  CLM357675      OtherPhysician                       NaN
#
# [2080809 rows x 4 columns]

# %%
tidy = data.melt(id_vars='Provider').rename(columns=str.title)

# %%
data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'Set', 'Status', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'Alzheimer', 'HeartFailure', 'KidneyDisease',
#        'Cancer', 'ObstrPulmonary', 'Depression', 'Diabetes', 'IschemicHeart',
#        'Osteoporasis', 'RheumatoidArthritis', 'Stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
#        'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'WhetherDead',
#        'NumProc', 'NumClaims', 'AdmissionDays', 'ClaimDays', 'Age',
#        'PotentialFraud'],
#       dtype='object')

# %%
sns.catplot(#y='InscClaimAmtReimbursed',
                x='NumChronics',
                hue='Gender',
            kind='count',
                data=outpat)

# %% [markdown]
# ## Aiko Questions

# %% [markdown]
# ### Set 1

# %% [markdown]
# 1. How many medical doctors are there in the train outpatient dataset?

# %%
train_docs = data[data.Set=='Train']

np.unique(train_docs[data.Status=='out'][['AttendingPhysician','OperatingPhysician','OtherPhysician']].fillna('').values.flatten()).shape
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (89771,)

# %% [markdown]
# 2. How many medical doctors are there in the train inpatient dataset? Do they match with those from the outpatient record?

# %%
np.unique(train_docs[data.Status=='in'][['AttendingPhysician','OperatingPhysician','OtherPhysician']].fillna('').values.flatten()).shape
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (18257,)

# %% [markdown]
# 3. Do those inpatient patients show worse health conditions (in terms of chronic diseases) than typical outpatient patients, or do those who have more visits to the providers have worse health conditions? Provide an analysis on these issues.

# %%
inpat = data[data.Status=='in']
outpat = data[data.Status=='out']

# %% [markdown]
# Let's count how many cases of chronic conditions exist in both inpatient and outpatient

# %%
chronic_count = data.groupby(['Status'])[['Alzheimer', 'HeartFailure', 'KidneyDisease',
       'Cancer', 'ObstrPulmonary', 'Depression', 'Diabetes', 'IschemicHeart',
       'Osteoporasis', 'RheumatoidArthritis', 'Stroke']].sum().reset_index()
chronic_count
# Out:
#   Status  Alzheimer  HeartFailure  KidneyDisease  Cancer  ObstrPulmonary  \
# 0     in      25095         36071          30125    9542           23999
# 1    out     253832        374002         256175   95917          192882
#
#    Depression  Diabetes  IschemicHeart  Osteoporasis  RheumatoidArthritis  \
# 0       25173     40004          42774         17534                18000
# 1      276103    449647         483902        202613               197681
#
#    Stroke
# 0    8513
# 1   62427

# %%
chronic_count['total'] =chronic_count.sum(axis=1)

# %%
chronic_prop = chronic_count.iloc[:,1:].div(chronic_count.total, axis=0)
chronic_prop.index = ['in','out']

# %%
chronic_prop = chronic_prop.reset_index()
chronic_prop.drop(columns=['total'],axis=1,inplace=True)

# %%
fig, ax1 = plt.subplots(figsize=(10, 10))

tidy = chronic_prop.melt(id_vars='index').rename(columns=str.title)

ax = sns.barplot(hue='Index', y='Value', x='Variable', data=tidy, ax=ax1)
#sns.despine(fig)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');
ax.set(xlabel='Chronic Condition', ylabel='% of Total Claims');
ax.figure.savefig("./plots/cc_props.png",bbox_inches='tight')

# %%
print(inpat.shape[0]*0.01)
print(outpat.shape[0]*0.01)
# Out:
# 500.25
# 6435.78

# %% [markdown]
# Or do those who have more visits to the providers have worse health conditions?

# %%
bene_visits = data.groupby(['BeneID','NumChronics','Status'])['Provider'].count().reset_index()
# .agg({
#     'Provider' : 'count',
#     'Alzheimer' : 'sum',
#     'HeartFailure' : 'sum',
#     'KidneyDisease' : 'sum',
#     'Cancer' : 'sum',
#     'ObstrPulmonary' : 'sum',
#     'Depression' : 'sum',
#     'Diabetes' : 'sum',
#     'IschemicHeart' : 'sum',
#     'Osteoporasis' : 'sum',
#     'RheumatoidArthritis' : 'sum',
#     'Stroke' : 'sum'
# })
bene_visits.sample(10)

#bene_visits['total'] =chronic_count.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-635-300858a804ec> in <module>
# ----> 1 bene_visits = data.groupby(['BeneID','NumChronics','Status'])['Provider'].count().reset_index()
#       2 # .agg({
#       3 #     'Provider' : 'count',
#       4 #     'Alzheimer' : 'sum',
#       5 #     'HeartFailure' : 'sum',
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'NumChronics'

# %%
visits_conds = bene_visits.groupby(['Status','NumChronics','Provider']).count().reset_index()
visits_conds.sample(4)
# Out:
#     Status  NumChronics  Provider  BeneID
# 28      in            7         1    3155
# 252    out            7        23       6
# 346    out           11        14       2
# 15      in            4         4       7

# %%
g = sns.stripplot(x='Provider',
              y='NumChronics',
                #hue='Status',
              jitter=0.1,
              hue = 'Status',
              size = np.log(visits_conds.BeneID),
                data=visits_conds)

#g.set(xticklabels = [0,10,20,30,32], horizontalalignment='right');
#g.set_xticks(range(len(visits_conds))) # <--- set the ticks first
#g.set_xticklabels([0,10,20,30])
g.set(xlabel='Number of Provider Visits', ylabel='Number of Chronic Conditions');
g.figure.savefig("./plots/visits_conds.png",bbox_inches='tight')

# %%
visits_conds.sort_values('Provider', ascending=False)
# Out:
#     Status  NumChronics  Provider  BeneID
# 229    out            6        32       1
# 200    out            5        30       1
# 228    out            6        28       3
# 283    out            8        28       1
# 309    out            9        28       2
# ..     ...          ...       ...     ...
# 310    out           10         1      18
# 201    out            6         1    1426
# 230    out            7         1     760
# 257    out            8         1     346
# 0       in            0         1     360
#
# [347 rows x 4 columns]

# %%
fig, ax1 = plt.subplots(figsize=(10, 10))

sns.barplot(hue='Status', x='NumChronics', y='Provider', data=visits_conds, ax=ax1)
#sns.despine(fig)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');
#ax.set(xlabel='Chronic Condition', ylabel='% of Total Claims');

# %%
bene_health = bene_visits.merge(data[['BeneID','NumChronics']], on='BeneID', how='left')
bene_health.shape
# Out:
# (922904, 4)

# %%
bene_health = bene_health.groupby(['Status','Provider','NumChronics']).count().reset_index()
bene_health.shape
# Out:
# (347, 4)

# %%
bene_health
# Out:
#     Status  Provider  NumChronics  BeneID
# 0       in         1            0     933
# 1       in         1            1    4194
# 2       in         1            2    9629
# 3       in         1            3   16468
# 4       in         1            4   24046
# ..     ...       ...          ...     ...
# 342    out        28            6      87
# 343    out        28            8      31
# 344    out        28            9      59
# 345    out        30            5      30
# 346    out        32            6      32
#
# [347 rows x 4 columns]

# %%
sns.stripplot(x='Provider',
                y='BeneID',
                hue='Status',
              jitter=0.25,
                data=bene_health)

# %%
sns.stripplot(x='NumChronics',
                y='BeneID',
                hue='Status',
                #alpha=0.5,
              jitter=0.25,
                data=bene_health)

# %%
inpat = data[data.Status=='in']
outpat = data[data.Status=='out']

ax = sns.catplot(x="NumChronics", 
                  hue='Gender', 
                  kind='count', 
                  data=inpat)

# %%
ax = sns.catplot(x="NumChronics", 
                  hue='Gender', 
                  kind='count', 
                  data=outpat)

# %% [markdown]
# 4. How many distinct patients (BeneIDs) are there in the in/out-patient datasets?

# %%
print('There are {} distinct Beneficiary IDs in the inpatient dataset'.format(inpat.BeneID.drop_duplicates().shape[0]))
print('There are {} distinct Beneficiary IDs in the outpatient dataset'.format(outpat.BeneID.drop_duplicates().shape[0]))
# Out:
# There are 37418 distinct Beneficiary IDs in the inpatient dataset
# There are 144189 distinct Beneficiary IDs in the outpatient dataset

# %% [markdown]
# 5. Do doctors serve for different providers? Study the distribution of hospital counts/doctor? Is it possible to characterize those doctors who move around among different providers?

# %%
data.groupby('Provider')['AttendingPhysician'].count().reset_index()
# Out:
#       Provider  AttendingPhysician
# 0     PRV51001                  25
# 1     PRV51002                 205
# 2     PRV51003                 132
# 3     PRV51004                 149
# 4     PRV51005                1165
# ...        ...                 ...
# 6758  PRV57759                  28
# 6759  PRV57760                  22
# 6760  PRV57761                  82
# 6761  PRV57762                   1
# 6762  PRV57763                 118
#
# [6763 rows x 2 columns]

# %%
doctors_providers = data.groupby(['AttendingPhysician','OperatingPhysician','OtherPhysician'])['Provider'].nunique().reset_index().sort_values('Provider', ascending=False).reset_index(drop=True)
doctors_providers.head(10)
# Out:
#      AttendingPhysician OperatingPhysician        OtherPhysician  Provider
# 0                                                                     1104
# 1     Dr. Harriet Abreu                                                  7
# 2  Dr. Eduardo Anderson                                                  7
# 3  Dr. Samantha Segovia                                                  7
# 4  Dr. Gotthold Scheibe                                                  7
# 5  Dr. Samantha Segovia                     Dr. Samantha Segovia         7
# 6  Dr. Úrsula del Valle                                                  7
# 7       Dr. Maren Owens                                                  6
# 8   Dr. Siegried Zavala                                                  6
# 9     Dr. Andrea Morris                                                  6

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-669-91d6e0b7ecd9> in <module>
# ----> 1 plt.hist(doctors_providers[(doctors_providers.Provider >2 and doctors_providers.Provider <8).any()].Provider)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
doctor_group = data.groupby(['AttendingPhysician','OperatingPhysician','OtherPhysician'])

doctors_summary = doctor_group.agg({
    'BeneID' : 'count', 
    'ClaimID' : 'count',
    'Provider': 'nunique',
    'InscClaimAmtReimbursed' : 'mean',
    'DeductibleAmtPaid': 'median', 
    'Race': 'median',
    'RenalDiseaseIndicator': 'sum', 
    'Alzheimer': 'sum', 
    'HeartFailure': 'sum', 
    'KidneyDisease': 'sum',
    'Cancer': 'sum', 
    'ObstrPulmonary': 'sum', 
    'Depression': 'sum', 
    'Diabetes': 'sum', 
    'IschemicHeart': 'sum',
    'Osteoporasis': 'sum', 
    'RheumatoidArthritis': 'sum', 
    'Stroke': 'sum',
    'IPAnnualReimbursementAmt': 'mean', 
    'IPAnnualDeductibleAmt': 'mean',
    'OPAnnualReimbursementAmt': 'mean', 
    'OPAnnualDeductibleAmt': 'mean', 
    'WhetherDead': 'sum',
    'NumProc': 'median', 
    'NumClaims' : 'median', 
    'AdmissionDays': 'median', 
    'ClaimDays': 'median', 
    'Age' : 'median',
    'NumChronics': 'median'
}).reset_index()
doctors_summary.head(10)
# Out:
#   AttendingPhysician OperatingPhysician        OtherPhysician  BeneID  \
# 0                                                                1823
# 1                                            Dr. Beth Benthin       1
# 2                                             Dr. Dorit Marín       2
# 3                                        Dr. Eugenia Mitchell       1
# 4                                              Dr. Evelio Ray       1
# 5                                         Dr. Gabriel Harloff       1
# 6                                            Dr. Hunter Meraz       1
# 7                                          Dr. Ingrid Daniels       1
# 8                                         Dr. Karina Franklin       1
# 9                                          Dr. Kimberly Kusch       1
#
#    ClaimID  Provider  InscClaimAmtReimbursed  DeductibleAmtPaid  Race  \
# 0     1823      1104               985.68294                0.0   1.0
# 1        1         1               500.00000               70.0   1.0
# 2        2         1              1200.00000               10.0   1.0
# 3        1         1               300.00000                0.0   1.0
# 4        1         1                30.00000                0.0   1.0
# 5        1         1                10.00000                0.0   5.0
# 6        1         1                40.00000                0.0   1.0
# 7        1         1                10.00000                0.0   1.0
# 8        1         1                60.00000                0.0   1.0
# 9        1         1              1800.00000                0.0   1.0
#
#    RenalDiseaseIndicator  ...  IPAnnualDeductibleAmt  \
# 0                    449  ...             764.936917
# 1                      0  ...               0.000000
# 2                      1  ...             534.000000
# 3                      0  ...               0.000000
# 4                      0  ...            1068.000000
# 5                      0  ...               0.000000
# 6                      0  ...               0.000000
# 7                      0  ...               0.000000
# 8                      1  ...               0.000000
# 9                      1  ...               0.000000
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  WhetherDead  NumProc  \
# 0               2143.422929             645.359298           19      0.0
# 1               3170.000000            1050.000000            0      0.0
# 2               5835.000000            1595.000000            0      0.0
# 3               1140.000000             500.000000            0      0.0
# 4               2230.000000             310.000000            0      0.0
# 5               3640.000000             870.000000            0      0.0
# 6               1180.000000             140.000000            0      0.0
# 7               1260.000000             310.000000            0      0.0
# 8               6590.000000            1790.000000            0      0.0
# 9               9590.000000            4070.000000            0      0.0
#
#    NumClaims  AdmissionDays  ClaimDays   Age  NumChronics
# 0        3.0            6.0        1.0  75.0          5.0
# 1        3.0            NaN        1.0  58.0          3.0
# 2        6.5            NaN       11.0  79.0          7.5
# 3        4.0            NaN        1.0  68.0          4.0
# 4        1.0            NaN        1.0  61.0          2.0
# 5        3.0            NaN        1.0  78.0          5.0
# 6        2.0            NaN        1.0  74.0          2.0
# 7        4.0            NaN        1.0  74.0          2.0
# 8        2.0            NaN        1.0  82.0          7.0
# 9        4.0            NaN       17.0  76.0          6.0
#
# [10 rows x 32 columns]

# %%
doctors_summary.sort_values('BeneID',ascending=False)
# Out:
#           AttendingPhysician  OperatingPhysician            OtherPhysician  \
# 0
# 198716  Dr. Thomas Benavídez
# 35965        Dr. Celia Brown
# 103949      Dr. Jessica Long
# 107592  Dr. Jolanthe Reising
# ...                      ...                 ...                       ...
# 92967     Dr. Isaac Villegas  Dr. Marcela Curiel          Dr. Jesse Zimmer
# 92968       Dr. Isaac Watson
# 92969       Dr. Isaac Watson                              Dr. Isaac Watson
# 92970       Dr. Isaac Weaver
# 107540      Dr. Jolanta Carr    Dr. Jolanta Carr  Dr. Juan Carlos Holloway
#
#         BeneID  ClaimID  Provider  InscClaimAmtReimbursed  DeductibleAmtPaid  \
# 0         1823     1823      1104              985.682940                0.0
# 198716    1332     1332         1              242.545045                0.0
# 35965      874      874         1              256.189931                0.0
# 103949     813      813         1              225.719557                0.0
# 107592     661      661         1              246.913767                0.0
# ...        ...      ...       ...                     ...                ...
# 92967        1        1         1             8000.000000             1068.0
# 92968        1        1         1                0.000000                0.0
# 92969        1        1         1              400.000000                0.0
# 92970        1        1         1               10.000000                0.0
# 107540       1        1         1              300.000000                0.0
#
#         Race  RenalDiseaseIndicator  ...  IPAnnualDeductibleAmt  \
# 0        1.0                    449  ...             764.936917
# 198716   1.0                    236  ...             427.897898
# 35965    1.0                    192  ...             443.093822
# 103949   1.0                    167  ...             463.119311
# 107592   1.0                    102  ...             445.500756
# ...      ...                    ...  ...                    ...
# 92967    1.0                      0  ...            1068.000000
# 92968    1.0                      0  ...               0.000000
# 92969    1.0                      1  ...               0.000000
# 92970    1.0                      1  ...               0.000000
# 107540   1.0                      0  ...               0.000000
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  WhetherDead  NumProc  \
# 0                    2143.422929             645.359298           19      0.0
# 198716               2276.201201             656.358859           15      0.0
# 35965                2318.524027             606.800915            7      0.0
# 103949               2053.419434             626.986470            9      0.0
# 107592               2314.629349             623.101362            4      0.0
# ...                          ...                    ...          ...      ...
# 92967                 440.000000             140.000000            0      1.0
# 92968                  30.000000             100.000000            0      0.0
# 92969                2690.000000             910.000000            0      0.0
# 92970                 220.000000               0.000000            0      0.0
# 107540               3330.000000             490.000000            0      0.0
#
#         NumClaims  AdmissionDays  ClaimDays   Age  NumChronics
# 0             3.0            6.0        1.0  75.0          5.0
# 198716        2.0            NaN        1.0  73.0          4.0
# 35965         2.0            NaN        1.0  76.0          4.0
# 103949        2.0            NaN        1.0  75.0          4.0
# 107592        2.0            NaN        1.0  74.0          4.0
# ...           ...            ...        ...   ...          ...
# 92967        10.0            9.0        9.0  71.0          4.0
# 92968         1.0            NaN        1.0  88.0          3.0
# 92969         1.0            NaN        1.0  81.0          7.0
# 92970         3.0            NaN        1.0  78.0          4.0
# 107540        2.0            NaN        1.0  72.0          0.0
#
# [215081 rows x 32 columns]

# %%
doctors_claims=doctors_claims.rename(columns = {"ClaimID":'ClaimsFiled'})

# %%
tidy = doctors_providers.melt(id_vars='Provider').rename(columns=str.title)
#tidy
doc_providers = tidy.groupby('Value')['Provider'].sum().reset_index().sort_values('Provider',ascending=False).reset_index(drop=True)

# %%
doc_providers
# Out:
#                      Value  Provider
# 0                             999053
# 1           Dr. Edward Paz      2958
# 2          Dr. Andrea Saiz      2813
# 3         Dr. Zacarías Lee      2459
# 4       Dr. Stella Montaño      2423
# ...                    ...       ...
# 123154         Dr. Jo King         1
# 123155      Dr. Jo Liebelt         1
# 123156     Dr. Jo Losekann         1
# 123157     Dr. Jo Montalvo         1
# 123158    Dr. Úrsula Zobel         1
#
# [123159 rows x 2 columns]

# %%
# sns.scatterplot(x = doc_providers.index,
#                 y = 'Value',
#                 data=doc_providers)

# %% [markdown]
# 6. Do patients go to different hospitals? Study the distribution of hospital counts/patient? It is possible to characterize those patients who receive services from a lot of different hospitals?

# %% [markdown]
# 7. Do the same providers provide both inpatient and outpatient services? Summarize your finding.

# %% [markdown]
# 8. Do Some of the same patients receive both inpatient and outpatient services? Summarize your finding.

# %%
np.unique(data['OperatingPhysician'].values.flatten())
# Out:
# array(['', 'Dr. Aaron Adler', 'Dr. Aaron Alvarez', ...,
#        'Dr. Úrsula Tucker', 'Dr. Úrsula Yang',
#        'Dr. Úrsula auch Schlauchin'], dtype=object)

# %%
docMelt = doctors_claims.melt(id_vars=['State','Provider','PotentialFraud','ClaimID','AttendingPhysician']).rename(columns=str.title)

# %%
docMelt.sample(4)
# Out:
#         State  Provider Potentialfraud  Claimid  Attendingphysician  \
# 513558     10  PRV54955            Yes        1    Dr. Camila Smith
# 181180     13  PRV52019            Yes        1  Dr. Cheryl Ornelas
# 135355     20  PRV52032            Yes        1      Dr. Urte Mccoy
# 200209     54  PRV56177             No        1   Dr. Destiny Reyes
#
#                   Variable                    Value
# 513558      OtherPhysician         Dr. Camila Smith
# 181180  OperatingPhysician          Dr. Inés Little
# 135355  OperatingPhysician  Dr. Urszula Wagenknecht
# 200209  OperatingPhysician    Dr. Detlev Villarreal

# %%
docMelt.columns = ['State','Provider', 'PotentialFraud', 'ClaimsFiled', 'Doc1',
       'Connection', 'Doc2']
docMelt.sample(3)
# Out:
#         State  Provider PotentialFraud  ClaimsFiled                 Doc1  \
# 193229      5  PRV51640             No            1   Dr. Daniel Centeno
# 215529     42  PRV55239             No            1  Dr. Katherine Rojas
# 507403      2  PRV57303             No            1     Dr. Israel Jasso
#
#                 Connection                    Doc2
# 193229  OperatingPhysician      Dr. Elizabeth Dörr
# 215529  OperatingPhysician  Dr. Katherine Schuster
# 507403      OtherPhysician        Dr. Israel Jasso

# %%
doctors_claims
# Out:
#        AttendingPhysician OperatingPhysician         OtherPhysician  Provider  \
# 25590    Dr. Reni Schüler                     Dr. Friedlinde Müller  PRV57103
# 239554    Dr. Jason Woods    Dr. Jason Woods      Dr. Nikolaus Báez  PRV55190
# 147672    Dr. Renato Webb                                            PRV52351
#
#        PotentialFraud  State  ClaimsFiled
# 25590             Yes     46            4
# 239554              ?     42            1
# 147672             No      1            1

# %%
data = pd.read_csv('./data/combinedData.csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (10,13,14,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Possible Routes
#
# - Link providers by physicians
#     - Physicians who work for multiple providers
# - Links by patients
#     - problematic
# - Link by shared codes
#     - can target specialties by looking at code classes (all psychiatric codes start with V)
# - Link by referrels (from one attending physician to an operating or other physician)
#
# - Time Series
#     - how many codes whether diagnostic or procedural are happening per visit
# - Look at multiple claims for single patients
#
# Fraud Tactics
# - providers break up multiple diagnosis codes into multiple claims across multiple days (**unbundling**)
#     - examples
#         - 5 diagnostics codes for provider A with one claim, provider B has one code for 5 claims
#             - facility charge accumulates per visit
#
# - throwing in fraudulent charges
#     - putting in a charge related to the condition (with a diagnosis code)
#     - putting in codes related to a patient condition but at a higher frequency relative to other providers
#
#
# - inpatient data
#  - incidences of 8 claims

# %%
target = pd.read_csv('./data/combinedTarget.csv')

# %%
data = data.merge(target, on=['Provider','Set'], how='left')

# %%
data.drop(columns=['Unnamed: 0_y','Unnamed: 0_x'], inplace=True)

# %%
data.fillna('',inplace=True)

# %%
doctors_claims = data.groupby(['AttendingPhysician','OperatingPhysician','OtherPhysician','Provider','PotentialFraud','State'])[['ClaimID']].nunique().reset_index().sort_values('ClaimID', ascending=False).reset_index(drop=True)
doctors_claims.head(10)
# Out:
#      AttendingPhysician OperatingPhysician OtherPhysician  Provider  \
# 0  Dr. Thomas Benavídez                                    PRV53918
# 1       Dr. Celia Brown                                    PRV54813
# 2      Dr. Jessica Long                                    PRV51567
# 3  Dr. Jolanthe Reising                                    PRV53797
# 4     Dr. Bryan Langern                                    PRV51459
# 5   Dr. Gotthard Fuller                                    PRV51459
# 6   Dr. Karina Franklin                                    PRV51459
# 7   Dr. Jessica Langern                                    PRV51459
# 8    Dr. Emilio Ramírez                                    PRV51459
# 9     Dr. Evelio Newman                                    PRV51196
#
#   PotentialFraud  State  ClaimID
# 0            Yes     23     1298
# 1             No     31      864
# 2            Yes      5      808
# 3            Yes     22      637
# 4            Yes      5      629
# 5            Yes      5      604
# 6            Yes      5      602
# 7            Yes      5      599
# 8            Yes      5      589
# 9             No      3      587

# %%
doctors_claims=doctors_claims.replace('',None, regex=True)

# %%
doctors_claims['Docs'] = doctors_claims[['AttendingPhysician','OperatingPhysician','OtherPhysician']].values.tolist()


#doctors_claims['Docs'] = doctors_claims['Docs'].apply(set)

# %%
doctors_claims.shape
# Out:
# (262617, 8)

# %%
doctors_claims.head(20)
# Out:
#       AttendingPhysician OperatingPhysician    OtherPhysician  Provider  \
# 0   Dr. Thomas Benavídez                                       PRV53918
# 1        Dr. Celia Brown                                       PRV54813
# 2       Dr. Jessica Long                                       PRV51567
# 3   Dr. Jolanthe Reising                                       PRV53797
# 4      Dr. Bryan Langern                                       PRV51459
# 5    Dr. Gotthard Fuller                                       PRV51459
# 6    Dr. Karina Franklin                                       PRV51459
# 7    Dr. Jessica Langern                                       PRV51459
# 8     Dr. Emilio Ramírez                                       PRV51459
# 9      Dr. Evelio Newman                                       PRV51196
# 10        Dr. Homero Ray                                       PRV51459
# 11   Dr. Angélica Thomas                                       PRV52338
# 12  Dr. Patricia Pacheco                                       PRV51459
# 13    Dr. Jessica Jordan                                       PRV52652
# 14   Dr. Michael Jäntsch                                       PRV51369
# 15       Dr. Maria Lopez                                       PRV52338
# 16      Dr. Helma Bailey                                       PRV55064
# 17      Dr. Jessica Long                     Dr. Jessica Long  PRV51567
# 18       Dr. Carina Cruz                     Dr. Jessica Long  PRV51369
# 19      Dr. Marcos Gunpf                     Dr. Jessica Long  PRV52628
#
#    PotentialFraud  State  ClaimID                                    Docs
# 0             Yes     23     1298                {, Dr. Thomas Benavídez}
# 1              No     31      864                     {, Dr. Celia Brown}
# 2             Yes      5      808                    {, Dr. Jessica Long}
# 3             Yes     22      637                {, Dr. Jolanthe Reising}
# 4             Yes      5      629                   {, Dr. Bryan Langern}
# 5             Yes      5      604                 {Dr. Gotthard Fuller, }
# 6             Yes      5      602                 {, Dr. Karina Franklin}
# 7             Yes      5      599                 {, Dr. Jessica Langern}
# 8             Yes      5      589                  {, Dr. Emilio Ramírez}
# 9              No      3      587                   {, Dr. Evelio Newman}
# 10            Yes      5      584                      {, Dr. Homero Ray}
# 11              ?     11      574                 {, Dr. Angélica Thomas}
# 12            Yes      5      571                {, Dr. Patricia Pacheco}
# 13            Yes     14      571                  {, Dr. Jessica Jordan}
# 14            Yes      5      549                 {, Dr. Michael Jäntsch}
# 15              ?     11      539                     {, Dr. Maria Lopez}
# 16             No     33      520                    {, Dr. Helma Bailey}
# 17            Yes      5      519                    {, Dr. Jessica Long}
# 18            Yes      5      512   {, Dr. Carina Cruz, Dr. Jessica Long}
# 19            Yes     14      509  {, Dr. Marcos Gunpf, Dr. Jessica Long}

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined
